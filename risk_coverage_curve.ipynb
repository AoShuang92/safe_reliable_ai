# %% [markdown]
# <a href="https://colab.research.google.com/github/AoShuang92/safe_reliable_ai/blob/main/risk_coverage_curve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams.update({'font.size': 22})

# coverage = [ 1, 0.9, 0.85, 0.8, 0.75, 0.7, 0.65, 0.6, 0.55, 0.5]
coverage = ['0' , 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ]
acc_resnet = np.array([ 0.708, 0.76, 0.785, 0.81, 0.833, 0.858, 0.879, 0.902, 0.92, 0.935])
acc_den121 = np.array([ 0.662, 0.712, 0.736, 0.761, 0.785, 0.811, 0.834, 0.86, 0.883, 0.903])
acc_vgg16 = np.array([ 0.643, 0.692, 0.713, 0.736, 0.761, 0.785, 0.81, 0.838, 0.861, 0.885])


accs = np.array([acc_resnet,acc_den121,acc_vgg16]).transpose()

fig, ax = plt.subplots(figsize= (7, 5))
# ax = plt.gca()
# ax.plot(coverage, accs) 
legends = ['ResNet34', 'DenseNet121', 'VGG16']
lineobjects = ax.plot(coverage, accs) 
ax.legend(lineobjects, legends, fontsize = 10)
ax.set_xlabel('Propotion Referred to Experts', fontsize = 12)
ax.set_ylabel('Accuracy', fontsize = 12)

# ax.set_xticks(coverage)
plt.savefig('cf100_rcc.pdf', bbox_inches = 'tight', dpi=300 )

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams.update({'font.size': 22})

# coverage = [ 1, 0.9, 0.85, 0.8, 0.75, 0.7, 0.65, 0.6, 0.55, 0.5]
coverage = ['0' , 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ]
acc_resnet = np.array([ 0.708, 0.76, 0.785, 0.81, 0.833, 0.858, 0.879, 0.902, 0.92, 0.935])
acc_den121 = np.array([ 0.662, 0.712, 0.736, 0.761, 0.785, 0.811, 0.834, 0.86, 0.883, 0.903])
acc_vgg16 = np.array([ 0.643, 0.692, 0.713, 0.736, 0.761, 0.785, 0.81, 0.838, 0.861, 0.885])

acc_in_vit = np.array([ 0.833, 0.88, 0.899, 0.919, 0.935, 0.951, 0.963, 0.97, 0.977, 0.982])
acc_in_swin = np.array([ 0.844, 0.885, 0.9, 0.913, 0.925, 0.935, 0.946, 0.955, 0.961, 0.965])
acc_in_rn34 = np.array([ 0.712, 0.765, 0.789, 0.812, 0.835, 0.855, 0.876, 0.897, 0.92, 0.937])
acc_in_vgg = np.array([ 0.699, 0.75, 0.774, 0.798, 0.821, 0.845, 0.868, 0.889, 0.91, 0.93])


accs = np.array([acc_resnet,acc_den121,acc_vgg16]).transpose()
acc_in = np.array([acc_in_vit, acc_in_swin, acc_in_rn34, acc_in_vgg ]).transpose()

fig, ax = plt.subplots(1,2, figsize= (12, 5))
# ax = plt.gca()
# ax.plot(coverage, accs) 
legends = ['ResNet34', 'DenseNet121', 'VGG16']
legentds_in = ['ViT','SwinT','ResNet34', 'VGG16']
lineobjects = ax[0].plot(coverage, accs) 
ax[0].legend(lineobjects, legends, fontsize = 16)
ax[0].set_xlabel('Propotion Referred to Experts', fontsize = 16)
ax[0].set_ylabel('Accuracy', fontsize = 16)
ax[0].set_title('CIFAR100 RCC', fontsize = 16)


lineobjects = ax[1].plot(coverage, acc_in) 
ax[1].legend(lineobjects, legentds_in, fontsize = 16)
ax[1].set_xlabel('Propotion Referred to Experts', fontsize = 16)
ax[1].set_ylabel('Accuracy', fontsize = 16)
ax[1].set_title('ImageNet RCC', fontsize = 16)


# ax.set_xticks(coverage)
plt.savefig('rcc.pdf', bbox_inches = 'tight', dpi=300 )
